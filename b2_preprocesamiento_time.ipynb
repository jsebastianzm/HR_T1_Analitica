# %%
import pandas as pd
import a_funciones as fn

# import

# %%
in_time = 'data\in_time.csv'
out_time = 'data\out_time.csv'

#Se procesa los dataframe con pandas y se almacenan
d_time_in = pd.read_csv(in_time)
d_time_out = pd.read_csv(out_time)

# %%
d_time_in.head()
d_time_in.rename(columns={'Unnamed: 0':'EmployeeID'}, inplace=True)
d_time_in.head()
# Out:
#    EmployeeID  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06  ...
# ...

# %%
# d_time_out.head()
d_time_out.rename(columns={'Unnamed: 0':'EmployeeID'}, inplace=True)
d_time_out.head()
# Out:
#    EmployeeID  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58  ...
# ...

# %%
d_time_in.isnull().sum()
# Out:
# EmployeeID       0
# 2015-01-01    4410
# 2015-01-02     209
# 2015-01-05     206
# 2015-01-06     228
#               ...
# 2015-12-25    4410
# 2015-12-28     234
# 2015-12-29     230
# 2015-12-30     265
# 2015-12-31     213
# Length: 262, dtype: int64

# %%
d_time_out.isnull().sum()
# Out:
# EmployeeID       0
# 2015-01-01    4410
# 2015-01-02     209
# 2015-01-05     206
# 2015-01-06     228
#               ...
# 2015-12-25    4410
# 2015-12-28     234
# 2015-12-29     230
# 2015-12-30     265
# 2015-12-31     213
# Length: 262, dtype: int64

# %%
for i in d_time_out.columns[1:]:
    d_time_in[i] = pd.to_datetime(d_time_in[i], format='%Y-%m-%d %H:%M:%S')
    d_time_out[i] = pd.to_datetime(d_time_out[i], format='%Y-%m-%d %H:%M:%S')

# %%
for i in d_time_out.columns[1:]:
    for j in d_time_out.columns[i][:]:
        hora = d_time_in[i][j].hour
        minutos = d_time_in[i][j].minute
        d_time_in['hora'] = d_time_in[i][j].apply(lambda x: x.hour)
        d_time_in['minutos'] = d_time_in[i][j].apply(lambda x: x.minute)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\codigos\HR_T1_Analitica\b2_preprocesamiento_time.ipynb Celda 9 in 2
#       <a href='vscode-notebook-cell:/c%3A/codigos/HR_T1_Analitica/b2_preprocesamiento_time.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> for i in d_time_out.columns[1:]:
# ----> <a href='vscode-notebook-cell:/c%3A/codigos/HR_T1_Analitica/b2_preprocesamiento_time.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a>     for j in d_time_out.columns[i][:]:
#       <a href='vscode-notebook-cell:/c%3A/codigos/HR_T1_Analitica/b2_preprocesamiento_time.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a>         hora = d_time_in[i][j].hour
#       <a href='vscode-notebook-cell:/c%3A/codigos/HR_T1_Analitica/b2_preprocesamiento_time.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a>         minutos = d_time_in[i][j].minute
#
# ...

# %%
d_time_in['2015-01-02'][0].hour
# Out:
# 9

# %%
d_time_in['2015-01-02']
# Out:
# 0      2015-01-02 09:43:45
# 1      2015-01-02 10:15:44
# 2      2015-01-02 10:17:41
# 3      2015-01-02 10:05:06
# 4      2015-01-02 10:28:17
#                ...
# 4405   2015-01-02 09:20:32
# 4406   2015-01-02 10:03:41
# 4407   2015-01-02 10:01:01
# 4408   2015-01-02 10:17:05
# 4409   2015-01-02 09:59:09
# Name: 2015-01-02, Length: 4410, dtype: datetime64[ns]

# %%
# # Supongamos que tienes dos DataFrames df1 y df2
# # con columnas 'hora_fin' y 'hora_inicio' que contienen tiempos en formato HH:MM:SS
# df1 = pd.DataFrame({'hora_fin': ['12:30:00', '14:45:00', '16:15:00']})
# df2 = pd.DataFrame({'hora_inicio': ['10:00:00', '12:30:00', '15:00:00']})

# # Convierte las columnas de tiempo en objetos timedelta
# df1['hora_fin'] = pd.to_timedelta(df1['hora_fin'])
# df2['hora_inicio'] = pd.to_timedelta(df2['hora_inicio'])

# # Realiza la resta para obtener la duración en cada fila
# duracion = df1['hora_fin'] - df2['hora_inicio']

# # Agrega la columna de duración al DataFrame original
# df1['duracion'] = duracion

# # Imprime el DataFrame resultante
# print(df1)
